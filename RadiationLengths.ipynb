# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

import mplhep as hep
hep.style.use("CMS")

plt.rcParams['figure.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
plt.rcParams['savefig.bbox']='tight'

plt.rcParams["figure.figsize"] = (10, 8)

try :
    import os
    os.mkdir("images")
except:
    pass

# %%
def get_theta(eta):
    return 2*np.arctan(np.exp(-eta))

# %%
nils={}
rads={}
#the numbers below are printed from running material_budget.sh

# %%
nils[('flange_-270cm_only',-4.35)] =  [0.00437657]
rads[('flange_-270cm_only',-4.35)] =  [0.0103216]
nils[('beampipe_flanges_and_ecal_endcap',-4.85)] =  [0.480045]
rads[('beampipe_flanges_and_ecal_endcap',-4.85)] =  [2.15005]
nils[('beampipe_flanges_and_ecal_endcap',-3.8)] =  [0.146735]
rads[('beampipe_flanges_and_ecal_endcap',-3.8)] =  [0.534865]
nils[('beampipe_and_flanges_only',-4.2)] =  [0.279806]
nils[('flange_-120cm_only',-4.5)] =  [0.00437619]
rads[('beampipe_and_flanges_only',-4.2)] =  [1.24799]
rads[('flange_-120cm_only',-4.5)] =  [0.0103207]
nils[('beampipe_and_flanges_only',-3.95)] =  [0.17506]
rads[('beampipe_and_flanges_only',-3.95)] =  [0.777765]
nils[('flange_-120cm_only',-4.7)] =  [0.00437583]
rads[('flange_-120cm_only',-4.7)] =  [0.0103198]
nils[('beampipe_and_flanges_only',-3.85)] =  [0.148927]
rads[('beampipe_and_flanges_only',-3.85)] =  [0.538873]
nils[('beampipe_and_flanges_only',-4.45)] =  [0.288658]
rads[('beampipe_and_flanges_only',-4.45)] =  [1.28884]
nils[('flange_-120cm_only',-4.65)] =  [0.00437591]
rads[('flange_-120cm_only',-4.65)] =  [0.01032]
nils[('flange_-120cm_only',-3.5)] =  [0.103839]
rads[('flange_-120cm_only',-3.5)] =  [0.456148]
nils[('flange_-270cm_only',-4.5)] =  [0.00437619]
nils[('beampipe_and_flanges_only',-4.85)] =  [0.480045]
rads[('flange_-270cm_only',-4.5)] =  [0.0103207]
rads[('beampipe_and_flanges_only',-4.85)] =  [2.15005]
nils[('flange_-270cm_only',-3.3)] =  [0.00438703]
rads[('flange_-270cm_only',-3.3)] =  [0.0103462]
nils[('flange_-120cm_only',-4.85)] =  [0.00437565]
rads[('flange_-120cm_only',-4.85)] =  [0.0103194]
nils[('beampipe_flanges_and_ecal_endcap',-3.6)] =  [1.09439]
rads[('beampipe_flanges_and_ecal_endcap',-3.6)] =  [23.0179]
nils[('flange_-120cm_only',-3.7)] =  [0.103777]
rads[('flange_-120cm_only',-3.7)] =  [0.455873]
nils[('flange_-270cm_only',-4.6)] =  [0.0680651]
rads[('flange_-270cm_only',-4.6)] =  [0.295806]
nils[('flange_-120cm_only',-3.45)] =  [0.00438394]
rads[('flange_-120cm_only',-3.45)] =  [0.0103389]
nils[('flange_-120cm_only',-3.35)] =  [0.0043859]
rads[('flange_-120cm_only',-3.35)] =  [0.0103435]
nils[('flange_-120cm_only',-4.2)] =  [0.0735997]
rads[('flange_-120cm_only',-4.2)] =  [0.320613]
nils[('beampipe_and_flanges_only',-4.3)] =  [0.238209]
rads[('beampipe_and_flanges_only',-4.3)] =  [1.06195]
nils[('beampipe_and_flanges_only',-4.55)] =  [0.329969]
rads[('beampipe_and_flanges_only',-4.55)] =  [1.47463]
nils[('beampipe_and_flanges_only',-4.1)] =  [0.256]
rads[('beampipe_and_flanges_only',-4.1)] =  [1.14093]
nils[('beampipe_and_flanges_only',-4.25)] =  [0.226393]
rads[('beampipe_and_flanges_only',-4.25)] =  [1.00877]
nils[('beampipe_flanges_and_ecal_endcap',-3.4)] =  [0.989299]
rads[('beampipe_flanges_and_ecal_endcap',-3.4)] =  [22.5771]
nils[('beampipe_flanges_and_ecal_endcap',-4.0)] =  [0.235369]
rads[('beampipe_flanges_and_ecal_endcap',-4.0)] =  [1.04814]
nils[('flange_-120cm_only',-4.15)] =  [0.0736032]
rads[('flange_-120cm_only',-4.15)] =  [0.320628]
nils[('flange_-270cm_only',-4.45)] =  [0.0043763]
rads[('flange_-270cm_only',-4.45)] =  [0.0103209]
nils[('beampipe_and_flanges_only',-3.6)] =  [0.139004]
rads[('beampipe_and_flanges_only',-3.6)] =  [0.520768]
nils[('beampipe_flanges_and_ecal_endcap',-4.3)] =  [0.238209]
nils[('beampipe_and_flanges_only',-4.05)] =  [0.245322]
rads[('beampipe_flanges_and_ecal_endcap',-4.3)] =  [1.06195]
rads[('beampipe_and_flanges_only',-4.05)] =  [1.09291]
nils[('flange_-270cm_only',-3.7)] =  [0.00438046]
rads[('flange_-270cm_only',-3.7)] =  [0.0103307]
nils[('beampipe_flanges_and_ecal_endcap',-3.35)] =  [0.988121]
rads[('beampipe_flanges_and_ecal_endcap',-3.35)] =  [22.5798]
nils[('flange_-270cm_only',-3.35)] =  [0.0043859]
rads[('flange_-270cm_only',-3.35)] =  [0.0103435]
nils[('flange_-270cm_only',-3.6)] =  [0.00438165]
rads[('flange_-270cm_only',-3.6)] =  [0.0103335]
nils[('beampipe_and_flanges_only',-4.7)] =  [0.47126]
rads[('beampipe_and_flanges_only',-4.7)] =  [2.10912]
nils[('beampipe_and_flanges_only',-3.8)] =  [0.146735]
rads[('beampipe_and_flanges_only',-3.8)] =  [0.534865]
nils[('flange_-120cm_only',-3.4)] =  [0.00438487]
rads[('flange_-120cm_only',-3.4)] =  [0.0103411]
nils[('flange_-120cm_only',-4.05)] =  [0.0736113]
rads[('flange_-120cm_only',-4.05)] =  [0.320663]
nils[('beampipe_flanges_and_ecal_endcap',-4.35)] =  [0.2537]
rads[('beampipe_flanges_and_ecal_endcap',-4.35)] =  [1.13162]
nils[('beampipe_and_flanges_only',-4.4)] =  [0.27047]
rads[('beampipe_and_flanges_only',-4.4)] =  [1.20704]
nils[('flange_-120cm_only',-3.8)] =  [0.103754]
rads[('flange_-120cm_only',-3.8)] =  [0.455772]
nils[('flange_-120cm_only',-4.45)] =  [0.0043763]
rads[('flange_-120cm_only',-4.45)] =  [0.0103209]
nils[('flange_-270cm_only',-4.15)] =  [0.00437729]
rads[('flange_-270cm_only',-4.15)] =  [0.0103232]
nils[('beampipe_and_flanges_only',-3.5)] =  [0.135694]
rads[('beampipe_and_flanges_only',-3.5)] =  [0.514765]
nils[('beampipe_and_flanges_only',-3.7)] =  [0.142672]
rads[('beampipe_and_flanges_only',-3.7)] =  [0.527447]
nils[('beampipe_and_flanges_only',-3.75)] =  [0.144652]
rads[('beampipe_and_flanges_only',-3.75)] =  [0.531059]
nils[('flange_-270cm_only',-4.8)] =  [0.0680606]
rads[('flange_-270cm_only',-4.8)] =  [0.295786]
nils[('flange_-270cm_only',-3.8)] =  [0.00437949]
rads[('flange_-270cm_only',-3.8)] =  [0.0103284]
nils[('flange_-270cm_only',-4.65)] =  [0.0680638]
rads[('flange_-270cm_only',-4.65)] =  [0.2958]
nils[('flange_-120cm_only',-4.0)] =  [0.073616]
rads[('flange_-120cm_only',-4.0)] =  [0.320684]
nils[('flange_-270cm_only',-4.1)] =  [0.00437751]
rads[('flange_-270cm_only',-4.1)] =  [0.0103238]
nils[('beampipe_and_flanges_only',-4.9)] =  [0.445864]
rads[('beampipe_and_flanges_only',-4.9)] =  [1.99742]
nils[('beampipe_flanges_and_ecal_endcap',-3.85)] =  [0.148927]
rads[('beampipe_flanges_and_ecal_endcap',-3.85)] =  [0.538873]
nils[('flange_-270cm_only',-4.3)] =  [0.00437672]
rads[('flange_-270cm_only',-4.3)] =  [0.0103219]
nils[('flange_-270cm_only',-4.0)] =  [0.00437805]
rads[('flange_-270cm_only',-4.0)] =  [0.010325]
nils[('flange_-120cm_only',-3.75)] =  [0.103765]
rads[('flange_-120cm_only',-3.75)] =  [0.45582]
nils[('flange_-120cm_only',-3.6)] =  [0.103805]
rads[('flange_-120cm_only',-3.6)] =  [0.455997]
nils[('beampipe_and_flanges_only',-3.35)] =  [0.0318123]
rads[('beampipe_and_flanges_only',-3.35)] =  [0.0608119]
nils[('flange_-120cm_only',-4.1)] =  [0.073607]
rads[('flange_-120cm_only',-4.1)] =  [0.320645]
nils[('flange_-270cm_only',-3.95)] =  [0.00437836]
rads[('flange_-270cm_only',-3.95)] =  [0.0103258]
nils[('flange_-270cm_only',-4.2)] =  [0.00437708]
rads[('flange_-270cm_only',-4.2)] =  [0.0103228]
nils[('flange_-270cm_only',-4.05)] =  [0.00437777]
rads[('flange_-270cm_only',-4.05)] =  [0.0103244]
nils[('beampipe_flanges_and_ecal_endcap',-3.65)] =  [1.18722]
rads[('beampipe_flanges_and_ecal_endcap',-3.65)] =  [18.2279]
nils[('flange_-270cm_only',-3.75)] =  [0.00437995]
rads[('flange_-270cm_only',-3.75)] =  [0.0103295]
nils[('flange_-270cm_only',-3.4)] =  [0.00438487]
rads[('flange_-270cm_only',-3.4)] =  [0.0103411]
nils[('flange_-120cm_only',-4.35)] =  [0.00437657]
rads[('flange_-120cm_only',-4.35)] =  [0.0103216]
nils[('flange_-120cm_only',-3.85)] =  [0.103744]
rads[('flange_-120cm_only',-3.85)] =  [0.455729]
nils[('flange_-120cm_only',-4.3)] =  [0.00437672]
rads[('flange_-120cm_only',-4.3)] =  [0.0103219]
nils[('flange_-120cm_only',-4.4)] =  [0.00437643]
rads[('flange_-120cm_only',-4.4)] =  [0.0103212]
nils[('flange_-270cm_only',-4.4)] =  [0.00437643]
rads[('flange_-270cm_only',-4.4)] =  [0.0103212]
nils[('flange_-120cm_only',-3.55)] =  [0.103821]
rads[('flange_-120cm_only',-3.55)] =  [0.456068]
nils[('beampipe_and_flanges_only',-4.0)] =  [0.235369]
rads[('beampipe_and_flanges_only',-4.0)] =  [1.04814]
nils[('flange_-120cm_only',-3.3)] =  [0.00438703]
rads[('flange_-120cm_only',-3.3)] =  [0.0103462]
nils[('beampipe_flanges_and_ecal_endcap',-4.4)] =  [0.27047]
rads[('beampipe_flanges_and_ecal_endcap',-4.4)] =  [1.20704]
nils[('beampipe_flanges_and_ecal_endcap',-4.1)] =  [0.256]
rads[('beampipe_flanges_and_ecal_endcap',-4.1)] =  [1.14093]
nils[('beampipe_flanges_and_ecal_endcap',-4.05)] =  [0.245322]
rads[('beampipe_flanges_and_ecal_endcap',-4.05)] =  [1.09291]
nils[('flange_-270cm_only',-3.5)] =  [0.0043831]
rads[('flange_-270cm_only',-3.5)] =  [0.0103369]
nils[('flange_-120cm_only',-4.25)] =  [0.00689716]
rads[('flange_-120cm_only',-4.25)] =  [0.0216194]
nils[('beampipe_flanges_and_ecal_endcap',-4.5)] =  [0.308429]
rads[('beampipe_flanges_and_ecal_endcap',-4.5)] =  [1.37775]
nils[('flange_-270cm_only',-4.85)] =  [0.0680597]
rads[('flange_-270cm_only',-4.85)] =  [0.295783]
nils[('beampipe_flanges_and_ecal_endcap',-3.9)] =  [0.151233]
rads[('beampipe_flanges_and_ecal_endcap',-3.9)] =  [0.543092]
nils[('beampipe_flanges_and_ecal_endcap',-4.65)] =  [0.442952]
rads[('beampipe_flanges_and_ecal_endcap',-4.65)] =  [1.9818]
nils[('beampipe_and_flanges_only',-4.8)] =  [0.536983]
rads[('beampipe_and_flanges_only',-4.8)] =  [2.4047]
nils[('beampipe_and_flanges_only',-3.65)] =  [0.140791]
rads[('beampipe_and_flanges_only',-3.65)] =  [0.524019]
nils[('flange_-120cm_only',-4.9)] =  [0.0043756]
rads[('flange_-120cm_only',-4.9)] =  [0.0103193]
nils[('beampipe_and_flanges_only',-4.5)] =  [0.308429]
rads[('beampipe_and_flanges_only',-4.5)] =  [1.37775]
nils[('beampipe_and_flanges_only',-4.65)] =  [0.442952]
rads[('beampipe_and_flanges_only',-4.65)] =  [1.9818]
nils[('beampipe_and_flanges_only',-4.6)] =  [0.417185]
rads[('beampipe_and_flanges_only',-4.6)] =  [1.86592]
nils[('beampipe_and_flanges_only',-4.75)] =  [0.502462]
rads[('beampipe_and_flanges_only',-4.75)] =  [2.24945]
nils[('flange_-120cm_only',-3.65)] =  [0.10379]
rads[('flange_-120cm_only',-3.65)] =  [0.455932]
nils[('flange_-120cm_only',-4.55)] =  [0.00437609]
rads[('flange_-120cm_only',-4.55)] =  [0.0103204]
nils[('flange_-270cm_only',-4.25)] =  [0.00437689]
rads[('flange_-270cm_only',-4.25)] =  [0.0103223]
nils[('flange_-270cm_only',-3.9)] =  [0.0043787]
rads[('flange_-270cm_only',-3.9)] =  [0.0103266]
nils[('beampipe_and_flanges_only',-3.4)] =  [0.033214]
rads[('beampipe_and_flanges_only',-3.4)] =  [0.0633909]
nils[('flange_-270cm_only',-3.55)] =  [0.00438234]
rads[('flange_-270cm_only',-3.55)] =  [0.0103352]
nils[('beampipe_flanges_and_ecal_endcap',-3.55)] =  [1.09284]
rads[('beampipe_flanges_and_ecal_endcap',-3.55)] =  [23.0184]
nils[('beampipe_and_flanges_only',-3.9)] =  [0.151233]
rads[('beampipe_and_flanges_only',-3.9)] =  [0.543092]
nils[('beampipe_flanges_and_ecal_endcap',-4.75)] =  [0.502462]
rads[('beampipe_flanges_and_ecal_endcap',-4.75)] =  [2.24945]
nils[('beampipe_flanges_and_ecal_endcap',-4.8)] =  [0.536983]
rads[('beampipe_flanges_and_ecal_endcap',-4.8)] =  [2.4047]
nils[('beampipe_flanges_and_ecal_endcap',-3.5)] =  [1.09139]
rads[('beampipe_flanges_and_ecal_endcap',-3.5)] =  [23.0194]
nils[('beampipe_flanges_and_ecal_endcap',-3.3)] =  [0.987036]
rads[('beampipe_flanges_and_ecal_endcap',-3.3)] =  [22.5832]
nils[('flange_-120cm_only',-4.75)] =  [0.00437577]
rads[('flange_-120cm_only',-4.75)] =  [0.0103197]
nils[('flange_-120cm_only',-4.8)] =  [0.0043757]
rads[('flange_-120cm_only',-4.8)] =  [0.0103195]
nils[('flange_-270cm_only',-3.65)] =  [0.00438103]
rads[('flange_-270cm_only',-3.65)] =  [0.0103321]
nils[('flange_-270cm_only',-4.9)] =  [0.0043756]
nils[('beampipe_flanges_and_ecal_endcap',-3.75)] =  [0.30565]
rads[('flange_-270cm_only',-4.9)] =  [0.0103193]
rads[('beampipe_flanges_and_ecal_endcap',-3.75)] =  [2.10367]
nils[('beampipe_flanges_and_ecal_endcap',-4.2)] =  [0.279806]
rads[('beampipe_flanges_and_ecal_endcap',-4.2)] =  [1.24799]
nils[('beampipe_and_flanges_only',-4.15)] =  [0.26747]
rads[('beampipe_and_flanges_only',-4.15)] =  [1.19252]
nils[('flange_-270cm_only',-4.7)] =  [0.0680626]
rads[('flange_-270cm_only',-4.7)] =  [0.295795]
nils[('flange_-270cm_only',-4.55)] =  [0.00437609]
rads[('flange_-270cm_only',-4.55)] =  [0.0103204]
nils[('flange_-270cm_only',-3.85)] =  [0.00437908]
rads[('flange_-270cm_only',-3.85)] =  [0.0103275]
nils[('beampipe_and_flanges_only',-3.45)] =  [0.034688]
rads[('beampipe_and_flanges_only',-3.45)] =  [0.0661027]
nils[('beampipe_flanges_and_ecal_endcap',-3.95)] =  [0.17506]
rads[('beampipe_flanges_and_ecal_endcap',-3.95)] =  [0.777765]
nils[('beampipe_flanges_and_ecal_endcap',-4.55)] =  [0.329969]
rads[('beampipe_flanges_and_ecal_endcap',-4.55)] =  [1.47463]
nils[('flange_-270cm_only',-3.45)] =  [0.00438394]
rads[('flange_-270cm_only',-3.45)] =  [0.0103389]
nils[('beampipe_and_flanges_only',-4.35)] =  [0.2537]
rads[('beampipe_and_flanges_only',-4.35)] =  [1.13162]
nils[('beampipe_and_flanges_only',-3.55)] =  [0.137306]
rads[('beampipe_and_flanges_only',-3.55)] =  [0.517686]
nils[('beampipe_and_flanges_only',-3.3)] =  [0.0304792]
rads[('beampipe_and_flanges_only',-3.3)] =  [0.0583594]
nils[('beampipe_flanges_and_ecal_endcap',-4.7)] =  [0.47126]
rads[('beampipe_flanges_and_ecal_endcap',-4.7)] =  [2.10912]
nils[('flange_-120cm_only',-4.6)] =  [0.004376]
rads[('flange_-120cm_only',-4.6)] =  [0.0103202]
nils[('beampipe_flanges_and_ecal_endcap',-4.45)] =  [0.288658]
rads[('beampipe_flanges_and_ecal_endcap',-4.45)] =  [1.28884]
nils[('beampipe_flanges_and_ecal_endcap',-4.15)] =  [0.26747]
rads[('beampipe_flanges_and_ecal_endcap',-4.15)] =  [1.19252]
nils[('flange_-120cm_only',-3.95)] =  [0.103727]
rads[('flange_-120cm_only',-3.95)] =  [0.455654]
nils[('beampipe_flanges_and_ecal_endcap',-4.9)] =  [0.445864]
rads[('beampipe_flanges_and_ecal_endcap',-4.9)] =  [1.99742]
nils[('beampipe_flanges_and_ecal_endcap',-3.7)] =  [0.827191]
rads[('beampipe_flanges_and_ecal_endcap',-3.7)] =  [8.52513]
nils[('flange_-270cm_only',-4.75)] =  [0.0680616]
rads[('flange_-270cm_only',-4.75)] =  [0.295791]
nils[('beampipe_flanges_and_ecal_endcap',-4.6)] =  [0.417185]
rads[('beampipe_flanges_and_ecal_endcap',-4.6)] =  [1.86592]
nils[('beampipe_flanges_and_ecal_endcap',-4.25)] =  [0.226393]
rads[('beampipe_flanges_and_ecal_endcap',-4.25)] =  [1.00877]
nils[('flange_-120cm_only',-3.9)] =  [0.103735]
rads[('flange_-120cm_only',-3.9)] =  [0.45569]
nils[('beampipe_flanges_and_ecal_endcap',-3.45)] =  [0.99057]
rads[('beampipe_flanges_and_ecal_endcap',-3.45)] =  [22.575]

# %%
nils[('backwards_insert',-4.7)] =  [0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.00458421, 0.00458421, 0.00458421, 0.00458421, 0.00458421, 0.00458421, 0.00458421, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449, 0.808449]
rads[('backwards_insert',-4.7)] =  [21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 0.0108112, 0.0108112, 0.0108112, 0.0108112, 0.0108112, 0.0108112, 0.0108112, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758, 21.1758]
nils[('backwards_insert',-4.8)] =  [0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.00458407, 0.00458407, 0.00458407, 0.00458407, 0.00458407, 0.00458407, 0.00458407, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424, 0.808424]
rads[('backwards_insert',-4.8)] =  [21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 0.0108109, 0.0108109, 0.0108109, 0.0108109, 0.0108109, 0.0108109, 0.0108109, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752, 21.1752]
nils[('backwards_insert',-3.55)] =  [0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.80965, 0.80965, 0.80965, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.80965, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.80965, 0.80965, 0.80965, 0.00459102, 0.00459102, 0.00459102, 0.00459102, 0.00459102]
rads[('backwards_insert',-3.55)] =  [0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 21.2073, 21.2073, 21.2073, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 21.2073, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 21.2073, 21.2073, 21.2073, 0.0108273, 0.0108273, 0.0108273, 0.0108273, 0.0108273]
nils[('backwards_insert',-3.5)] =  [0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.356848, 0.809791, 0.356756, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.356817, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.809791, 0.356817, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.356756, 0.809791, 0.356848, 0.00459182, 0.00459182, 0.00459182, 0.00459182, 0.00459182]
nils[('backwards_insert',-3.8)] =  [0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124, 0.809124]
rads[('backwards_insert',-3.5)] =  [0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 9.25322, 21.2109, 9.25049, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 9.25231, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 21.2109, 9.25231, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 9.25049, 21.2109, 9.25322, 0.0108292, 0.0108292, 0.0108292, 0.0108292, 0.0108292]
rads[('backwards_insert',-3.8)] =  [21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935, 21.1935]
nils[('backwards_insert',-4.2)] =  [0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.00458551, 0.00458551, 0.00458551, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679, 0.808679]
rads[('backwards_insert',-4.2)] =  [21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 0.0108143, 0.0108143, 0.0108143, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818, 21.1818]
nils[('backwards_insert',-3.45)] =  [0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.809946, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.809946, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.809946, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927, 0.0045927]
rads[('backwards_insert',-3.45)] =  [0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 21.215, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 21.215, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 21.215, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313, 0.0108313]
nils[('backwards_insert',-3.95)] =  [0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915, 0.808915]
rads[('backwards_insert',-3.95)] =  [21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188, 21.188]
nils[('backwards_insert',-3.35)] =  [0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.810307, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475, 0.00459475]
rads[('backwards_insert',-3.35)] =  [0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 21.2245, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361, 0.0108361]
nils[('backwards_insert',-4.05)] =  [0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806, 0.808806]
rads[('backwards_insert',-4.05)] =  [21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851, 21.1851]
nils[('backwards_insert',-4.45)] =  [0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.0045847, 0.0045847, 0.0045847, 0.0045847, 0.0045847, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536, 0.808536]
rads[('backwards_insert',-4.45)] =  [21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 0.0108124, 0.0108124, 0.0108124, 0.0108124, 0.0108124, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781, 21.1781]
nils[('backwards_insert',-3.85)] =  [0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047, 0.809047]
rads[('backwards_insert',-3.85)] =  [21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915, 21.1915]
nils[('backwards_insert',-4.85)] =  [0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.00458401, 0.00458401, 0.00458401, 0.00458401, 0.00458401, 0.00458401, 0.00458401, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151, 0.0468151]
rads[('backwards_insert',-4.85)] =  [1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 0.0108108, 0.0108108, 0.0108108, 0.0108108, 0.0108108, 0.0108108, 0.0108108, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922, 1.12922]
nils[('backwards_insert',-3.6)] =  [0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.603573, 0.809523, 0.809523, 0.809523, 0.603503, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.60355, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.809523, 0.60355, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.0045903, 0.603503, 0.809523, 0.809523, 0.809523, 0.603573, 0.0045903, 0.0045903, 0.0045903, 0.0045903]
rads[('backwards_insert',-3.6)] =  [0.0108256, 0.0108256, 0.0108256, 0.0108256, 15.7664, 21.2039, 21.2039, 21.2039, 15.7643, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 15.7657, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 21.2039, 15.7657, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 0.0108256, 15.7643, 21.2039, 21.2039, 21.2039, 15.7664, 0.0108256, 0.0108256, 0.0108256, 0.0108256]
nils[('backwards_insert',-4.3)] =  [0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.00458514, 0.00458514, 0.00458514, 0.00458514, 0.00458514, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613, 0.808613]
rads[('backwards_insert',-4.3)] =  [21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 0.0108134, 0.0108134, 0.0108134, 0.0108134, 0.0108134, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801, 21.1801]
nils[('backwards_insert',-4.75)] =  [0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.00458414, 0.00458414, 0.00458414, 0.00458414, 0.00458414, 0.00458414, 0.00458414, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436, 0.808436]
rads[('backwards_insert',-4.75)] =  [21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 0.0108111, 0.0108111, 0.0108111, 0.0108111, 0.0108111, 0.0108111, 0.0108111, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755, 21.1755]
nils[('backwards_insert',-4.5)] =  [0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.00458458, 0.00458458, 0.00458458, 0.00458458, 0.00458458, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515, 0.808515]
rads[('backwards_insert',-4.5)] =  [21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 0.0108121, 0.0108121, 0.0108121, 0.0108121, 0.0108121, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775, 21.1775]
nils[('backwards_insert',-4.9)] =  [0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396, 0.00458396]
rads[('backwards_insert',-4.9)] =  [0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106, 0.0108106]
nils[('backwards_insert',-3.65)] =  [0.00458965, 0.00458965, 0.00458965, 0.316294, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.316245, 0.00458965, 0.00458965, 0.00458965, 0.00458965, 0.00458965, 0.316278, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.316278, 0.00458965, 0.00458965, 0.00458965, 0.00458965, 0.00458965, 0.316245, 0.809408, 0.809408, 0.809408, 0.809408, 0.809408, 0.316294, 0.00458965, 0.00458965, 0.00458965]
rads[('backwards_insert',-3.65)] =  [0.0108241, 0.0108241, 0.0108241, 8.18508, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 8.18361, 0.0108241, 0.0108241, 0.0108241, 0.0108241, 0.0108241, 8.18459, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 8.18459, 0.0108241, 0.0108241, 0.0108241, 0.0108241, 0.0108241, 8.18361, 21.2009, 21.2009, 21.2009, 21.2009, 21.2009, 8.18508, 0.0108241, 0.0108241, 0.0108241]
nils[('backwards_insert',-4.65)] =  [0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.357936, 0.00458429, 0.00458429, 0.00458429, 0.00458429, 0.00458429, 0.357936, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463, 0.808463]
rads[('backwards_insert',-4.65)] =  [21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 9.28742, 0.0108114, 0.0108114, 0.0108114, 0.0108114, 0.0108114, 9.28742, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762, 21.1762]
nils[('backwards_insert',-4.55)] =  [0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.00458447, 0.00458447, 0.00458447, 0.00458447, 0.00458447, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496, 0.808496]
rads[('backwards_insert',-4.55)] =  [21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 0.0108119, 0.0108119, 0.0108119, 0.0108119, 0.0108119, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177, 21.177]
nils[('backwards_insert',-4.1)] =  [0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.657217, 0.0320848, 0.657217, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759, 0.808759]
rads[('backwards_insert',-4.1)] =  [21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 17.1534, 0.822598, 17.1534, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839, 21.1839]
nils[('backwards_insert',-4.0)] =  [0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857, 0.808857]
rads[('backwards_insert',-4.0)] =  [21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865, 21.1865]
nils[('backwards_insert',-3.4)] =  [0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.654115, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.654197, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.810118, 0.654197, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.654115, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367, 0.00459367]
rads[('backwards_insert',-3.4)] =  [0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 17.1284, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 17.1308, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 21.2195, 17.1308, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 17.1284, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336, 0.0108336]
nils[('backwards_insert',-4.4)] =  [0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.00458483, 0.00458483, 0.00458483, 0.00458483, 0.00458483, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559, 0.808559]
rads[('backwards_insert',-4.4)] =  [21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 0.0108127, 0.0108127, 0.0108127, 0.0108127, 0.0108127, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787, 21.1787]
nils[('backwards_insert',-3.9)] =  [0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978, 0.808978]
rads[('backwards_insert',-3.9)] =  [21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896, 21.1896]
nils[('backwards_insert',-3.3)] =  [0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.810517, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594, 0.00459594]
rads[('backwards_insert',-3.3)] =  [0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 21.23, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389, 0.0108389]
nils[('backwards_insert',-4.6)] =  [0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.00458438, 0.00458438, 0.00458438, 0.00458438, 0.00458438, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478, 0.808478]
rads[('backwards_insert',-4.6)] =  [21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 0.0108116, 0.0108116, 0.0108116, 0.0108116, 0.0108116, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766, 21.1766]
nils[('backwards_insert',-4.35)] =  [0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.00458498, 0.00458498, 0.00458498, 0.00458498, 0.00458498, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584, 0.808584]
rads[('backwards_insert',-4.35)] =  [21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 0.0108131, 0.0108131, 0.0108131, 0.0108131, 0.0108131, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793, 21.1793]
nils[('backwards_insert',-4.25)] =  [0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.635733, 0.00458532, 0.00458532, 0.00458532, 0.635733, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644, 0.808644]
rads[('backwards_insert',-4.25)] =  [21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 16.5897, 0.0108139, 0.0108139, 0.0108139, 16.5897, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809, 21.1809]
nils[('backwards_insert',-4.15)] =  [0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.00458573, 0.00458573, 0.00458573, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717, 0.808717]
rads[('backwards_insert',-4.15)] =  [21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 0.0108148, 0.0108148, 0.0108148, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828, 21.1828]
nils[('backwards_insert',-3.7)] =  [0.00458906, 0.00458906, 0.426269, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.426264, 0.00458906, 0.00458906, 0.00458906, 0.426267, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.426267, 0.00458906, 0.00458906, 0.00458906, 0.426264, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.809304, 0.426269, 0.00458906, 0.00458906]
rads[('backwards_insert',-3.7)] =  [0.0108227, 0.0108227, 11.1085, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 11.1085, 0.0108227, 0.0108227, 0.0108227, 11.1085, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 11.1085, 0.0108227, 0.0108227, 0.0108227, 11.1085, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 21.1982, 11.1085, 0.0108227, 0.0108227]
nils[('backwards_insert',-3.75)] =  [0.731334, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.731334, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.731334, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.80921, 0.731334]
rads[('backwards_insert',-3.75)] =  [19.1536, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 19.1536, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 19.1536, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 21.1957, 19.1536]
#done

# %%
def rads_plot(tag='backwards_insert', mineta=-4.8, maxeta=-3.5, log=False, add_mat=None, scale=1, maxN=100000):



    from matplotlib import ticker as ticker
    phi=np.linspace(-np.pi, np.pi, len(nils[(tag, -4.0)]))
    eta=np.linspace(mineta, maxeta, int((maxeta-mineta)/.05+2))
    x=phi*180/np.pi
    y=eta
    z=np.array([rads[(tag,int(i*20)/20)] for i in y])
    if add_mat is not None:
        z=np.array([[z[i][j]+add_mat(eta[i],phi[j]) for j in range(len(z[0]))] for i in range(len(z))])
    
    z=z*(z<maxN)+maxN*(z>=maxN)
    
    #locator=ticker.LogLocator()
    #locator.view_limits(0.01, 25)
    contour = plt.contourf(x,y,z, 40, locator=locator if log else None, cmap='plasma')
    cb = plt.colorbar(contour)
    cb.set_label("# of $X_0$s traversed")
    plt.xlabel("$\phi$ [deg]")
    plt.ylabel("$\eta$")
    plt.xlim(-180, 180)

# %%
x_fid,y_fid=(np.array([0.16410256410256352, -1.4104131248952472, -2.9579884139160852, -4.4521438606958705, -5.8673140512820545, -7.179285031354396, -8.365608613696788, -9.405986472904317, -10.282617455358706, -10.980502161902129, -11.487699591715435, -11.79553145615283, -11.898730666666667, -11.898730666666667, -11.795531456152828, -11.487699591715435, -10.980502161902125, -10.282617455358702, -9.405986472904317, -8.365608613696788, -7.179285031354388, -5.867314051282045, -4.452143860695865, -2.95798841391608, -1.4104131248952445, 0.16410256410256352, 0.16410256410256427, 9.711340307692307, 11.285855996690128, 12.833431285710962, 14.327586732490747, 15.742756923076927, 17.054727903149267, 18.241051485491663, 19.28142934469919, 20.158060327153578, 20.855945033697, 21.363142463510307, 21.6709743279477, 21.77417353846154, 21.6709743279477, 21.363142463510307, 20.855945033696997, 20.15806032715357, 19.281429344699188, 18.24105148549166, 17.054727903149264, 15.742756923076922, 14.32758673249074, 12.833431285710954, 11.285855996690117, 9.711340307692307, 0.16410256410256427, 0.16410256410256352]), 
             np.array([-12.06283323076923, -11.959634020255393, -11.651802155818, -11.144604726004692, -10.446720019461267, -9.57008903700688, -8.529711177799353, -7.343387595456962, -6.0314166153846145, -4.616246424798436, -3.122090978018651, -1.5745156889978102, -1.4772710104709863e-15, 1.4772710104709863e-15, 1.5745156889978207, 3.1220909780186563, 4.61624642479844, 6.03141661538462, 7.343387595456962, 8.529711177799353, 9.570089037006886, 10.446720019461273, 11.144604726004694, 11.651802155818002, 11.959634020255395, 12.06283323076923, 12.06283323076923, 12.06283323076923, 11.959634020255391, 11.651802155817998, 11.14460472600469, 10.446720019461265, 9.57008903700688, 8.52971117779935, 7.3433875954569565, 6.031416615384614, 4.616246424798429, 3.1220909780186443, 1.5745156889978087, 0.0, -1.574515688997814, -3.1220909780186497, -4.616246424798434, -6.031416615384618, -7.343387595456961, -8.529711177799351, -9.570089037006882, -10.446720019461269, -11.144604726004692, -11.651802155818, -11.959634020255393, -12.06283323076923, -12.06283323076923, -12.06283323076923]))

# %%
rads_plot(tag='backwards_insert', mineta=-4.9, maxeta=-3.3, log=False, add_mat=None, maxN=20.17)
plt.title("material from FDC")

#draw fiducial region (ECal shadow)

#first circular segment
R1=12.06
X1=21.77-R1
Z=-320
eta1=-np.log(np.tan(np.arctan2(R1,Z)/2))
arg=dict(color='green', ls='--')
plt.plot([-180, -90], [eta1, eta1], **arg)
plt.plot([180, 90], [eta1, eta1], **arg)
plt.text(-172, -3.92, "ECal shadow", fontsize=20, color='green')

#straight segments
x=np.linspace(0, X1, 10)
y=np.linspace(R1,R1, 10)
eta=-np.log(np.tan(np.arctan2(np.hypot(x,y),Z)/2))
phi=np.arctan2(y,x)
plt.plot(180/np.pi*phi, eta, **arg)
plt.plot(-180/np.pi*phi, eta, **arg)

#second circular segment:
phi_p=np.linspace(-np.pi/2, np.pi/2, 21)
x=X1+R1*np.cos(phi_p)
y=R1*np.sin(phi_p)
eta=-np.log(np.tan(np.arctan2(np.hypot(x,y),Z)/2))
phi=np.arctan2(y,x)
plt.plot(180/np.pi*phi, eta, **arg)

#phi_fid=np.arctan2(y_fid,x_fid)
#eta_fid=-np.log(np.tan(np.arctan2(np.hypot(x_fid, y_fid),-320)/2))
#plt.plot(phi_fid*180/np.pi, eta_fid, color='magenta')

plt.savefig("images/material_budget_fdc.pdf")
plt.show()
#rads_plot("epic_full", log=False)
#plt.show()

# %%
#additional material not included in the dd4hep file
def add_mat(eta, phi):
    theta=get_theta(eta)
    X0s=0
    #circular flange, modeled as a solid cylinder
    z=-120
    r=np.tan(theta)*z
    
    rad_length_Al=8.897
    if r<7.612 and r>3.5:
        length=3.9624
        X0s+=length/rad_length_Al
        
    #now for the cam-shaped flange
    z=-269.72
    OR1=11.106/2
    IR1=8.2346/2
    x1=0
    
    
    OR2=2.8440
    IR2=3.1475/2
    x2=-0.025*z
    
    x=z*np.tan(theta)*np.cos(phi)
    y=z*np.tan(theta)*np.sin(phi)
    
    r1=np.hypot(x, y)
    r2=np.hypot(x-x2, y)
    
    if r1<OR1 and r1>IR1 or r2<OR2 and r2>IR2:
        length=2.54
        X0s+=length/rad_length_Al
    
    
    
    return X0s

# %%
def rads_plot_1d(tag='beampipe_and_flange_only', mineta=-4.7, maxeta=-3.3, plot_type="nrad",**arg):
    eta=np.linspace(mineta, maxeta, int((maxeta-mineta)/.05+2))
    

    x=eta
    y= np.array([rads[(tag,int(i*20)/20)][-1] for i in eta])
    
    if min(y)<0.01:
        y-=min(y)
    
    print(y)
    
    if plot_type=="nrad":
        plt.plot(x,y, **arg)
        plt.ylabel("# of $X_0$s traversed (circular section)")
    elif plot_type=="prob_no_shower":
        plt.plot(x,np.exp(-y), **arg)
        plt.ylabel("prob. of not showering (circ. section)")
    
    
    plt.xlabel("$\eta$")
    #plt.ylim(0)
    plt.legend()

# %%
rads_plot_1d('beampipe_and_flanges_only',label='beampipe including flanges')
rads_plot_1d('flange_-120cm_only',label='flange at z=$-$120 cm', ls='--')
rads_plot_1d('flange_-270cm_only',label='flange at z=$-$270 cm', ls=':')
#rads_plot_1d('beampipe_flanges_and_ecal_endcap', label='total including Ecal endcap')
plt.ylim(0,2.5)
plt.savefig('images/rad_lengths_1d.pdf')
plt.show()

rads_plot_1d('beampipe_and_flanges_only',label='beampipe including flanges', plot_type="prob_no_shower")
plt.ylim(0,1)
plt.savefig('images/shower_prob_1d.pdf')
plt.show()
# Out:
# [2.10912   1.9818    1.86592   1.47463   1.37775   1.28884   1.20704
#  1.13162   1.06195   1.00877   1.24799   1.19252   1.14093   1.09291
#  1.04814   0.777765  0.543092  0.538873  0.534865  0.531059  0.527447
#  0.524019  0.520768  0.517686  0.514765  0.0661027 0.0633909 0.0608119
#  0.0583594 0.0583594]
# [0.0103198 0.01032   0.0103202 0.0103204 0.0103207 0.0103209 0.0103212
#  0.0103216 0.0103219 0.0216194 0.320613  0.320628  0.320645  0.320663
#  0.320684  0.455654  0.45569   0.455729  0.455772  0.45582   0.455873
#  0.455932  0.455997  0.456068  0.456148  0.0103389 0.0103411 0.0103435
#  0.0103462 0.0103462]
# [0.295795  0.2958    0.295806  0.0103204 0.0103207 0.0103209 0.0103212
#  0.0103216 0.0103219 0.0103223 0.0103228 0.0103232 0.0103238 0.0103244
#  0.010325  0.0103258 0.0103266 0.0103275 0.0103284 0.0103295 0.0103307
#  0.0103321 0.0103335 0.0103352 0.0103369 0.0103389 0.0103411 0.0103435
#  0.0103462 0.0103462]
# ...

# %%
mineta=-4.71; maxeta=-3.3
eta=np.linspace(mineta, maxeta, int((maxeta-mineta)/.05+2))
y={}
for tag in "beampipe_and_flanges_only", "flange_-120cm_only", "flange_-270cm_only":
    y[tag]= np.array([rads[(tag,int(i*20)/20)][-1] for i in eta])

#flanges_only=y["flange_-120cm_only"]+y["flange_-270cm_only"]
flanges_only=y["flange_-270cm_only"]

air=np.min(flanges_only)
flanges_only-=air#remove the air
y_current = y["beampipe_and_flanges_only"]-air-y["flange_-120cm_only"]
beampipe_no_flanges=y_current - flanges_only

X0_Be=35.28
X0_Al=8.897

print(X0_Al/X0_Be)

eta_transition=-3.97
s=(1.5/2.0)
y_new_thin_Al=beampipe_no_flanges*(s*(eta<eta_transition)+1*(eta>=eta_transition))+flanges_only


s=X0_Al/X0_Be*(0.76/2.0)
y_new_thinner_Be=beampipe_no_flanges*(s*(eta<eta_transition)+1*(eta>=eta_transition))+flanges_only


plt.plot(eta,y_current, label='beampipe including flanges:\n  Al, 2.0 mm thick (current design)')
plt.plot(eta,y_new_thin_Al, label='  Al, 1.5 mm thickness', ls='-.')

#smooth out notch caused by transition between the recalculated Beryllium and the real Beryllium in the model
slc=(eta>-3.5)|(eta<-4.0)
plt.plot(eta[slc],y_new_thinner_Be[slc], label='  Be, 0.8 mm thickness', ls='--')
plt.plot(eta,flanges_only, label='contribution from flange @ z=-270 cm', ls=':')

#plt.text(-4.75, 0.07, 'flange at\nz=$-$270 cm', color='tab:red', fontsize=14)
#plt.text(-4.15, 0.07, 'flange at\nz=$-$120 cm', color='tab:red', fontsize=20)

plt.plot()
plt.ylabel("# of $X_0$s traversed")
plt.ylim(0)
plt.xlabel("$\eta$")
#plt.ylim(0)

plt.axhline(1.0, color='0.3', ls=':', alpha=0.7)
plt.text(-3.8, 1.03, "1 rad. length", fontsize=20)
plt.legend(fontsize=20)
plt.savefig("images/proposed_beampipe.pdf")
# Out:
# 0.2521825396825397

# %%
0.5/np.sin(get_theta(-4.4))/X0_Al
# Out:
# 2.2890622121184285

# %%
0.05/np.sin(get_theta(-4.4))/X0_Al
# Out:
# 0.2289062212118429

# %%
1.5/X0_Al
# Out:
# 0.16859615600764302

# %%
nils[('epic_ip6_extended',-4.85)] =  [0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254, 0.480254]
rads[('epic_ip6_extended',-4.85)] =  [2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054, 2.15054]
nils[('epic_ip6_extended',-4.25)] =  [0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.532193, 0.921868, 2.89477e-10, 0.921868, 0.532193, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082, 0.224082]
rads[('epic_ip6_extended',-4.25)] =  [0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 2.37985, 4.13057, 6.82693e-10, 4.13057, 2.37985, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967, 0.997967]
nils[('epic_ip6_extended',-4.65)] =  [0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.796403, 0.570519, 0.796403, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472, 0.379472]
rads[('epic_ip6_extended',-4.65)] =  [1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 3.56635, 2.55432, 3.56635, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682, 1.69682]
nils[('epic_ip6_extended',-4.0)] =  [0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.340166, 0.359072, 0.340166, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339, 0.166339]
rads[('epic_ip6_extended',-4.0)] =  [0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 1.51762, 1.60251, 1.51762, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276, 0.738276]
nils[('epic_ip6_extended',-3.6)] =  [0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894, 0.0397894]
rads[('epic_ip6_extended',-3.6)] =  [0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969, 0.0755969]
nils[('epic_ip6_extended',-3.95)] =  [0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.193377, 0.290401, 0.193377, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197, 0.0759197]
rads[('epic_ip6_extended',-3.95)] =  [0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.859431, 1.29434, 0.859431, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928, 0.332928]
nils[('epic_ip6_extended',-4.7)] =  [0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.619881, 1.0495, 0.619881, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781, 0.407781]
rads[('epic_ip6_extended',-4.7)] =  [1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 2.77487, 4.70087, 2.77487, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413, 1.82413]
nils[('epic_ip6_extended',-4.35)] =  [0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 1.21011, 2.89456e-10, 2.89456e-10, 2.89456e-10, 1.21011, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909, 0.253909]
rads[('epic_ip6_extended',-4.35)] =  [1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 5.41975, 6.82642e-10, 6.82642e-10, 6.82642e-10, 5.41975, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211, 1.13211]
nils[('epic_ip6_extended',-3.7)] =  [0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848, 0.0434848]
rads[('epic_ip6_extended',-3.7)] =  [0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964, 0.0823964]
nils[('epic_ip6_extended',-3.65)] =  [0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908, 0.0415908]
rads[('epic_ip6_extended',-3.65)] =  [0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115, 0.0789115]
nils[('epic_ip6_extended',-4.1)] =  [0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.376607, 0.46405, 0.510784, 0.46405, 0.376607, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979, 0.186979]
rads[('epic_ip6_extended',-4.1)] =  [0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 1.68125, 2.07388, 2.28372, 2.07388, 1.68125, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103, 0.831103]
nils[('epic_ip6_extended',-4.4)] =  [0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.992864, 2.89446e-10, 2.89446e-10, 2.89446e-10, 0.992864, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678, 0.270678]
rads[('epic_ip6_extended',-4.4)] =  [1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 4.44636, 6.82621e-10, 6.82621e-10, 6.82621e-10, 4.44636, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753, 1.20753]
nils[('epic_ip6_extended',-3.85)] =  [0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709, 0.0497709]
rads[('epic_ip6_extended',-3.85)] =  [0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629, 0.0939629]
nils[('epic_ip6_extended',-4.6)] =  [0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.942926, 0.869354, 0.942926, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704, 0.353704]
rads[('epic_ip6_extended',-4.6)] =  [1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 4.22361, 3.89534, 4.22361, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093, 1.58093]
nils[('epic_ip6_extended',-4.9)] =  [0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072, 0.446072]
rads[('epic_ip6_extended',-4.9)] =  [1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791, 1.99791]
nils[('epic_ip6_extended',-3.5)] =  [0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465, 0.0364465]
rads[('epic_ip6_extended',-3.5)] =  [0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464, 0.0694464]
nils[('epic_ip6_extended',-4.45)] =  [0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 1.03274, 2.89438e-10, 2.89438e-10, 2.89438e-10, 1.03274, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867, 0.288867]
nils[('epic_ip6_extended',-3.75)] =  [0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761, 0.0454761]
rads[('epic_ip6_extended',-4.45)] =  [1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 4.62503, 6.82601e-10, 6.82601e-10, 6.82601e-10, 4.62503, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933, 1.28933]
rads[('epic_ip6_extended',-3.75)] =  [0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604, 0.0860604]
nils[('epic_ip6_extended',-3.3)] =  [0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881, 0.0306881]
rads[('epic_ip6_extended',-3.3)] =  [0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521, 0.0588521]
nils[('epic_ip6_extended',-4.5)] =  [0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 1.26189, 0.289591, 2.89431e-10, 0.289591, 1.26189, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637, 0.308637]
rads[('epic_ip6_extended',-4.5)] =  [1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 5.65169, 1.29775, 6.82583e-10, 1.29775, 5.65169, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825, 1.37825]
nils[('epic_ip6_extended',-3.35)] =  [0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211, 0.0320211]
rads[('epic_ip6_extended',-3.35)] =  [0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045, 0.0613045]
nils[('epic_ip6_extended',-3.8)] =  [0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697, 0.0475697]
rads[('epic_ip6_extended',-3.8)] =  [0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127, 0.0899127]
nils[('epic_ip6_extended',-4.55)] =  [0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.790523, 0.869238, 2.89424e-10, 0.869238, 0.790523, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177, 0.330177]
rads[('epic_ip6_extended',-4.55)] =  [1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 3.53862, 3.89482, 6.82567e-10, 3.89482, 3.53862, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512, 1.47512]
nils[('epic_ip6_extended',-4.05)] =  [0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.312997, 0.394483, 0.4234, 0.394483, 0.312997, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297, 0.176297]
rads[('epic_ip6_extended',-4.05)] =  [0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 1.39582, 1.76151, 1.89136, 1.76151, 1.39582, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061, 0.783061]
nils[('epic_ip6_extended',-3.55)] =  [0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761, 0.0380761]
rads[('epic_ip6_extended',-3.55)] =  [0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445, 0.0724445]
nils[('epic_ip6_extended',-4.2)] =  [0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.477466, 0.709425, 0.955814, 0.709425, 0.477466, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792, 0.210792]
rads[('epic_ip6_extended',-4.2)] =  [0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 2.13412, 3.17652, 4.28265, 3.17652, 2.13412, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196, 0.938196]
nils[('epic_ip6_extended',-4.3)] =  [0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 1.05689, 0.0716099, 2.89466e-10, 0.0716099, 1.05689, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418, 0.238418]
rads[('epic_ip6_extended',-4.3)] =  [1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 4.73221, 0.320906, 6.82666e-10, 0.320906, 4.73221, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244, 1.06244]
nils[('epic_ip6_extended',-3.45)] =  [0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968, 0.0348968]
rads[('epic_ip6_extended',-3.45)] =  [0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595, 0.066595]
nils[('epic_ip6_extended',-4.15)] =  [0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.424617, 0.62849, 1.04357, 0.62849, 0.424617, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452, 0.198452]
rads[('epic_ip6_extended',-4.15)] =  [0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 1.89682, 2.81168, 4.67355, 2.81168, 1.89682, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702, 0.882702]
nils[('epic_ip6_extended',-3.4)] =  [0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228, 0.0334228]
rads[('epic_ip6_extended',-3.4)] =  [0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833, 0.0638833]
nils[('epic_ip6_extended',-4.75)] =  [0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985, 0.438985]
rads[('epic_ip6_extended',-4.75)] =  [1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447, 1.96447]
nils[('epic_ip6_extended',-3.9)] =  [0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085, 0.052085]
rads[('epic_ip6_extended',-3.9)] =  [0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221, 0.098221]
nils[('epic_ip6_extended',-4.8)] =  [0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506, 0.473506]
rads[('epic_ip6_extended',-4.8)] =  [2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972, 2.11972]

# %%
rads_plot(tag='epic_ip6_extended', mineta=-4.9, maxeta=-3.3, log=False, add_mat=None, maxN=20.17)
